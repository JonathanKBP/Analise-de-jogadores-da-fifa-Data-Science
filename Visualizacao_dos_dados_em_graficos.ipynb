# %% [markdown]
# <a href="https://colab.research.google.com/github/JonathanKBP/Analise-de-jogadores-da-fifa-Data-Science/blob/main/Visualizacao_dos_dados_em_graficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('sds.fifa_atualizado.csv')

# %%
dados.head()
# Out:
#    Unnamed: 0             Nome  Idade  ...           Time  Salario  Total_Pontos
# 0           0         V. Thill     20  ...    CD Nacional     2000          1551
# 1           1   S. Wamangituka     20  ...  VfB Stuttgart    13000          1847
# 2           2       14 A. Wolf     31  ...      AS Monaco    30000          1621
# 3           3    N. De la Cruz     23  ...    River Plate    17000          2180
# 4           4             Isco     28  ...    Real Madrid   190000          2077
#
# [5 rows x 9 columns]

# %%
dados.drop('Unnamed: 0', axis=1, inplace=True)

# %%
dados.head()
# Out:
#               Nome  Idade Posicao  ...           Time  Salario Total_Pontos
# 0         V. Thill     20      RW  ...    CD Nacional     2000         1551
# 1   S. Wamangituka     20      RM  ...  VfB Stuttgart    13000         1847
# 2       14 A. Wolf     31      CB  ...      AS Monaco    30000         1621
# 3    N. De la Cruz     23      CM  ...    River Plate    17000         2180
# 4             Isco     28     CAM  ...    Real Madrid   190000         2077
#
# [5 rows x 8 columns]

# %%
dados.plot()

# %%
dados.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1ac53940f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ac53c25c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1ac5373828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ac5324a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1ac52d4cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ac5306f60>]],
#       dtype=object)

# %%
dados.corr()
# Out:
#                  Idade     Media  Potencial   Salario  Total_Pontos
# Idade         1.000000  0.626329  -0.194001  0.636867      0.530865
# Media         0.626329  1.000000   0.509920  0.747361      0.810249
# Potencial    -0.194001  0.509920   1.000000  0.391635      0.367507
# Salario       0.636867  0.747361   0.391635  1.000000      0.582078
# Total_Pontos  0.530865  0.810249   0.367507  0.582078      1.000000

# %%
dados.columns
# Out:
# Index(['Nome', 'Idade', 'Posicao', 'Media', 'Potencial', 'Time', 'Salario',
#        'Total_Pontos'],
#       dtype='object')

# %%
colunas = ['Nome', 'Idade', 'Posicao', 'Media', 'Potencial', 'Time', 'Salario',
       'Total_Pontos']

# %%
plt.figure(figsize=(20, 14))

# %%
sns.heatmap(dados[colunas].corr(), annot=True)

# %%
sns.clustermap(dados[colunas].corr(), annot=False)

# %%
plt.figure(figsize=(10, 5))
pl = sns.boxplot(x=dados['Time'][0:100], y=dados['Media'], palette='hls');
pl.set_title(label='Média por clube');
plt.xlabel('Time')
plt.ylabel('Média')
plt.yticks(rotation=80)
plt.ylim(85, 95)
# Out:
# (85.0, 95.0)

# %%
sns.jointplot(dados['Idade'], dados['Media'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.jointplot(dados['Media'], dados['Salario'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot('Idade', 'Media', data=dados)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.catplot('Idade', 'Media', data=dados, kind='box').fig.set_size_inches(11, 7)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
